# %% [markdown]
# # Logistic Regression

# %% [markdown]
# problem statement :

# %% [markdown]
#  Build a machine learning model to predict whether a person makes over 50K a year or not
#         https://drive.google.com/open?id=1XVi34snXnh6qW2u71jwc05oCRnpOXoWF

# %%
#importing necessary libraries

#importing pandas library to handel dataset
import pandas as pd
#importing numpy library for faster matrix calculations
import numpy as np
#importing matplotlib for plotting data graphs
import matplotlib.pyplot as plt
#importing seaborn advanced plotting library
import seaborn as sns

#loading data set
data_set = pd.read_csv('classification_2.csv',names=[
"Age", "Workclass", "fnlwgt", "Education", "Education-Num", "Marital Status",
"Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss",
"Hours per week", "Country", "Target"])
data_set.head()
# Out:
#    Age          Workclass  fnlwgt   Education  Education-Num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         Marital Status          Occupation    Relationship    Race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capital Gain  Capital Loss  Hours per week         Country  Target
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %% [markdown]
# ### data pre-processing

# %%
data_set.describe()
# Out:
#           Workclass     Education  Marital Status    Occupation  Capital Gain  \
# count  32561.000000  32561.000000    32561.000000  32561.000000  32561.000000
# mean       4.868892     11.298210        3.611836      7.572740      9.892234
# std        1.455960      3.870264        1.506222      4.228857      0.738537
# min        1.000000      1.000000        1.000000      1.000000     -0.000000
# 25%        5.000000     10.000000        3.000000      4.000000     10.000000
# 50%        5.000000     12.000000        3.000000      8.000000     10.000000
# 75%        5.000000     13.000000        5.000000     11.000000     10.000000
# max        9.000000     16.000000        7.000000     15.000000     10.000000
#
#        Capital Loss       Country        Target
# count  32561.000000  32561.000000  32561.000000
# mean       9.799578     37.718866      0.759190
# std        0.925069      7.823782      0.427581
# min       -0.000000      1.000000      0.000000
# 25%       10.000000     40.000000      1.000000
# 50%       10.000000     40.000000      1.000000
# 75%       10.000000     40.000000      1.000000
# max       10.000000     42.000000      1.000000

# %%
#checking for list of columns present in data set
data_set.columns
# Out:
# Index(['Age', 'Workclass', 'fnlwgt', 'Education', 'Education-Num',
#        'Marital Status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital Gain', 'Capital Loss', 'Hours per week', 'Country', 'Target'],
#       dtype='object')

# %%
# #assigning numerical values in our target variable columns
data_set.Target.replace([' <=50K',' >50K'],[1,0], inplace=True)
data_set.head()
# Out:
#    Age          Workclass  fnlwgt   Education  Education-Num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         Marital Status          Occupation    Relationship    Race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capital Gain  Capital Loss  Hours per week         Country  Target
# 0          2174             0              40   United-States       1
# 1             0             0              13   United-States       1
# 2             0             0              40   United-States       1
# 3             0             0              40   United-States       1
# 4             0             0              40            Cuba       1

# %%
#checking catagories in our target variable column and their sependency on other columns
data_set.groupby('Target').mean()
# Out:
#               Age        fnlwgt  Education-Num  Capital Gain  Capital Loss  \
# Target
# 0       44.249841  188005.00000      11.611657   4006.142456    195.001530
# 1       36.783738  190340.86517       9.595065    148.752468     53.142921
#
#         Hours per week
# Target
# 0            45.473026
# 1            38.840210

# %%
#checking dependency of target column on workclass column <<<note only target column mean>>
data_set.groupby('Workclass').mean()
# Out:
#                          Age         fnlwgt  Education-Num  Capital Gain  \
# Workclass
#  ?                 40.960240  188516.338235       9.260349    606.795752
#  Federal-gov       42.590625  185221.243750      10.973958    833.232292
#  Local-gov         41.751075  188639.712852      11.042045    880.202580
#  Never-worked      20.571429  225989.571429       7.428571      0.000000
#  Private           36.797585  192764.114734       9.879714    889.217792
#  Self-emp-inc      46.017025  175981.344086      11.137097   4875.693548
#  Self-emp-not-inc  44.969697  175608.641480      10.226289   1886.061787
#  State-gov         39.436055  184136.613251      11.375963    701.699538
#  Without-pay       47.785714  174267.500000       9.071429    487.857143
#
#                    Capital Loss  Hours per week    Target
# Workclass
#  ?                    60.760349       31.919390  0.895969
#  Federal-gov         112.268750       41.379167  0.613542
#  Local-gov           109.854276       40.982800  0.705208
#  Never-worked          0.000000       28.428571  1.000000
#  Private              80.008724       40.267096  0.781327
#  Self-emp-inc        155.138889       48.818100  0.442652
#  Self-emp-not-inc    116.631641       44.421881  0.715073
#  State-gov            83.256549       39.031587  0.728043
#  Without-pay           0.000000       32.714286  1.000000

# %%
#checking dependency of target column on education column <<<note only target column mean>>
data_set.groupby('Education').mean()
# Out:
#                      Age         fnlwgt  Education-Num  Capital Gain  \
# Education
#  10th          37.429796  196832.465166            6.0    404.574491
#  11th          32.355745  194928.077447            7.0    215.097872
#  12th          32.000000  199097.508083            8.0    284.087760
#  1st-4th       46.142857  239303.000000            2.0    125.875000
#  5th-6th       42.885886  232448.333333            3.0    176.021021
#  7th-8th       48.445820  188079.171827            4.0    233.939628
#  9th           41.060311  202485.066148            5.0    342.089494
#  Assoc-acdm    37.381443  193424.093721           12.0    640.399250
#  Assoc-voc     38.553546  181936.016643           11.0    715.051375
#  Bachelors     38.904949  188055.914846           13.0   1756.299533
#  Doctorate     47.702179  186698.760291           16.0   4770.145278
#  HS-grad       38.974479  189538.739739            9.0    576.800114
#  Masters       44.049913  179852.362739           14.0   2562.563552
#  Preschool     42.764706  235889.372549            1.0    898.392157
#  Prof-school   44.746528  185663.706597           15.0  10414.416667
#  Some-college  35.756275  188742.922370           10.0    598.824167
#
#                Capital Loss  Hours per week    Target
# Education
#  10th             56.845659       37.052519  0.933548
#  11th             50.079149       33.925957  0.948936
#  12th             32.337182       35.780600  0.923788
#  1st-4th          48.327381       38.255952  0.964286
#  5th-6th          68.252252       38.897898  0.951952
#  7th-8th          65.668731       39.366873  0.938080
#  9th              28.998054       38.044747  0.947471
#  Assoc-acdm       93.418932       40.504217  0.751640
#  Assoc-voc        72.754703       41.610709  0.738784
#  Bachelors       118.350327       42.614006  0.585247
#  Doctorate       262.845036       46.973366  0.259080
#  HS-grad          70.466622       40.575374  0.840491
#  Masters         166.719675       43.836332  0.443413
#  Preschool        66.490196       36.647059  1.000000
#  Prof-school     231.203125       47.425347  0.265625
#  Some-college     71.637087       38.852284  0.809765

# %%
#checking dependency of target column on marital status column <<<note only target column mean>>
data_set.groupby('Marital Status').mean()
# Out:
#                               Age         fnlwgt  Education-Num  Capital Gain  \
# Marital Status
#  Divorced               43.041639  185802.790457      10.030385    728.414810
#  Married-AF-spouse      32.478261  188165.565217      10.173913    432.652174
#  Married-civ-spouse     43.247596  186763.172877      10.320646   1764.859509
#  Married-spouse-absent  40.578947  193141.760766       9.308612    653.983254
#  Never-married          28.150988  195383.308996       9.962464    376.588318
#  Separated              39.354146  206444.325854       9.293659    535.568780
#  Widowed                58.975831  174159.042296       9.093656    571.071501
#
#                         Capital Loss  Hours per week    Target
# Marital Status
#  Divorced                  64.600720       41.246680  0.895791
#  Married-AF-spouse          0.000000       41.130435  0.565217
#  Married-civ-spouse       122.439103       43.284856  0.553152
#  Married-spouse-absent     57.779904       39.669856  0.918660
#  Never-married             52.345502       36.939998  0.954039
#  Separated                 58.110244       39.301463  0.935610
#  Widowed                   79.666667       32.979859  0.914401

# %%
#checking dependency of target column on occupation column <<<note only target column mean>>
data_set.groupby('Occupation').mean()
# Out:
#                           Age         fnlwgt  Education-Num  Capital Gain  \
# Occupation
#  ?                  40.882800  188658.667390       9.253391    604.491047
#  Adm-clerical       36.964456  192043.396286      10.113528    495.954907
#  Armed-Forces       30.222222  215425.888889      10.111111      0.000000
#  Craft-repair       39.031471  192132.599658       9.110759    649.512808
#  Exec-managerial    42.169208  184414.012543      11.449090   2262.772996
#  Farming-fishing    41.211268  170190.176056       8.608652    589.726358
#  Handlers-cleaners  32.165693  204391.006569       8.510219    257.572993
#  Machine-op-inspct  37.715285  195040.877622       8.487512    328.689311
#  Other-service      34.949621  188608.452200       8.779666    191.301669
#  Priv-house-serv    41.724832  201107.523490       7.362416    279.852349
#  Prof-specialty     40.517633  185296.613285      12.905072   2726.699517
#  Protective-serv    38.953775  202039.953775      10.184900    708.098613
#  Sales              37.353973  190885.892055      10.299726   1319.829315
#  Tech-support       37.022629  192098.301724      10.992457    673.552802
#  Transport-moving   40.197871  190366.355041       8.767063    490.323732
#
#                     Capital Loss  Hours per week    Target
# Occupation
#  ?                     60.529571       31.906131  0.896365
#  Adm-clerical          60.794430       37.558355  0.865517
#  Armed-Forces         209.666667       40.666667  0.888889
#  Craft-repair          88.465235       42.304221  0.773359
#  Exec-managerial      138.838416       44.987703  0.515986
#  Farming-fishing       63.075453       46.989940  0.884306
#  Handlers-cleaners     45.635766       37.947445  0.937226
#  Machine-op-inspct     61.706294       40.755744  0.875125
#  Other-service         38.250683       34.701669  0.958422
#  Priv-house-serv       21.449664       32.885906  0.993289
#  Prof-specialty       136.139372       42.386715  0.550966
#  Protective-serv       78.334361       42.870570  0.674884
#  Sales                 98.300548       40.781096  0.730685
#  Tech-support          98.665948       39.432112  0.695043
#  Transport-moving      81.480902       44.656230  0.799624

# %%
#checking dependency of target column on relationship column <<<note only target column mean>>
data_set.groupby('Relationship').mean()
# Out:
#                        Age         fnlwgt  Education-Num  Capital Gain  \
# Relationship
#  Husband         43.818616  187074.862503      10.326461   1795.062230
#  Not-in-family   38.346057  191131.795304      10.315593    743.327273
#  Other-relative  33.164118  205059.821611       8.786952    279.595311
#  Own-child       24.827940  193175.408840       9.486188    155.655485
#  Unmarried       40.293964  191128.405688       9.642194    455.031050
#  Wife            39.846301  181849.507653      10.463010   1659.791454
#
#                  Capital Loss  Hours per week    Target
# Relationship
#  Husband           124.160919       44.120139  0.551429
#  Not-in-family      75.390728       40.595665  0.896930
#  Other-relative     51.332314       37.006116  0.962283
#  Own-child          39.511839       33.269337  0.986780
#  Unmarried          41.464887       39.103018  0.936738
#  Wife              118.006378       36.861607  0.524872

# %%
#checking dependency of target column on race column <<<note only target column mean>>
data_set.groupby('Race').mean()
# Out:
#                            Age         fnlwgt  Education-Num  Capital Gain  \
# Race
#  Amer-Indian-Eskimo  37.173633  120831.147910       9.311897    625.266881
#  Asian-Pac-Islander  37.746872  159940.609240      10.960539   1478.358037
#  Black               37.767926  228013.124200       9.486236    609.940461
#  Other               33.457565  197124.191882       8.841328    934.660517
#  White               38.769881  187298.064280      10.135246   1121.660375
#
#                      Capital Loss  Hours per week    Target
# Race
#  Amer-Indian-Eskimo     34.176849       40.048232  0.884244
#  Asian-Pac-Islander     97.222329       40.127045  0.734360
#  Black                  60.385083       38.422855  0.876120
#  Other                  61.070111       39.468635  0.907749
#  White                  90.806155       40.689100  0.744140

# %%
#checking dependency of target column on sex column <<<note only target column mean>>
data_set.groupby('Sex').mean()
# Out:
#                Age         fnlwgt  Education-Num  Capital Gain  Capital Loss  \
# Sex
#  Female  36.858230  185746.311206      10.035744    568.410547     61.187633
#  Male    39.433547  191771.449013      10.102891   1329.370078    100.213309
#
#          Hours per week    Target
# Sex
#  Female       36.410361  0.890539
#  Male         42.428086  0.694263

# %%
#checking dependency of target column on country column <<<note only target column mean>>
data_set.groupby('Country').mean()
# Out:
#                                    Age         fnlwgt  Education-Num  \
# Country
#  ?                           38.725557  193300.897084      10.598628
#  Cambodia                    37.789474  193080.368421       8.789474
#  Canada                      42.545455  179852.933884      10.652893
#  China                       42.533333  179047.986667      11.120000
#  Columbia                    39.711864  225149.406780       9.372881
#  Cuba                        45.768421  246291.347368       9.600000
#  Dominican-Republic          37.728571  192089.557143       7.114286
#  Ecuador                     36.642857  185858.821429       9.464286
#  El-Salvador                 34.132075  254392.971698       6.839623
#  England                     41.155556  182375.166667      11.011111
#  France                      38.965517  192050.896552      12.241379
#  Germany                     39.255474  189325.313869      10.985401
#  Greece                      46.206897  143466.206897       9.724138
#  Guatemala                   32.421875  265163.343750       6.031250
#  Haiti                       38.272727  209019.431818       8.931818
#  Holand-Netherlands          32.000000   27882.000000      10.000000
#  Honduras                    33.846154  255591.307692       8.692308
#  Hong                        33.650000  222352.750000      10.600000
#  Hungary                     49.384615  180488.461538      10.769231
#  India                       38.090000  168539.090000      12.430000
#  Iran                        39.418605  182211.395349      12.395349
#  Ireland                     36.458333  137997.583333      10.083333
#  Italy                       46.424658  181685.397260       8.849315
#  Jamaica                     35.592593  212155.234568       9.851852
#  Japan                       38.241935  185703.629032      11.435484
#  Laos                        34.722222  211108.000000       8.555556
#  Mexico                      33.290824  289724.746501       6.135303
#  Nicaragua                   33.617647  294574.117647       8.705882
#  Outlying-US(Guam-USVI-etc)  38.714286  204487.785714      10.285714
#  Peru                        35.258065  274559.354839       9.354839
#  Philippines                 39.444444  166115.116162      10.868687
#  Poland                      43.116667  183904.016667      10.100000
#  Portugal                    40.297297  148621.675676       6.702703
#  Puerto-Rico                 40.508772  202535.728070       8.289474
#  Scotland                    40.416667  168946.083333      10.250000
#  South                       38.750000  163481.787500      10.912500
#  Taiwan                      33.823529  186441.392157      13.294118
#  Thailand                    34.944444  184166.666667      10.944444
#  Trinadad&Tobago             41.315789  212812.315789       8.263158
#  United-States               38.655674  187069.021152      10.169455
#  Vietnam                     34.059701  163283.925373       9.656716
#  Yugoslavia                  38.812500  215963.937500       9.937500
#
#                              Capital Gain  Capital Loss  Hours per week  \
# Country
#  ?                            1806.518010    118.265866       41.512864
#  Cambodia                     1027.842105    183.052632       40.894737
#  Canada                       1504.132231    129.933884       40.404959
#  China                         366.480000    179.520000       37.786667
#  Columbia                      180.610169     27.152542       39.067797
#  Cuba                          367.231579     70.042105       39.157895
#  Dominican-Republic           1476.057143     25.171429       42.471429
#  Ecuador                       527.607143      0.000000       39.571429
#  El-Salvador                   574.320755     31.113208       36.792453
#  England                       864.722222     82.755556       41.833333
#  France                        547.034483      0.000000       45.068966
#  Germany                       887.094891     77.978102       41.014599
#  Greece                       1283.896552    295.448276       44.241379
#  Guatemala                     230.828125     24.906250       39.234375
#  Haiti                           0.000000     73.295455       36.909091
#  Holand-Netherlands              0.000000   2205.000000       40.000000
#  Honduras                        0.000000    146.307692       36.307692
#  Hong                            0.000000     98.850000       40.900000
#  Hungary                       716.615385    128.307692       35.615385
#  India                        3604.920000    131.120000       41.530000
#  Iran                         2044.651163    126.813953       43.976744
#  Ireland                       324.458333     78.625000       42.416667
#  Italy                         611.506849     27.082192       41.602740
#  Jamaica                       475.135802      0.000000       38.592593
#  Japan                        2546.225806     57.532258       43.693548
#  Laos                          160.277778      0.000000       40.333333
#  Mexico                        347.027994     24.744946       40.340591
#  Nicaragua                     199.823529    100.794118       36.176471
#  Outlying-US(Guam-USVI-etc)      0.000000      0.000000       41.857143
#  Peru                           59.064516     59.612903       35.387097
#  Philippines                  1018.343434     98.954545       39.595960
#  Poland                        684.283333     34.183333       38.333333
#  Portugal                      228.378378      0.000000       41.891892
#  Puerto-Rico                   317.192982     55.228070       38.570175
#  Scotland                      431.500000      0.000000       41.250000
#  South                        1869.737500    169.425000       42.412500
#  Taiwan                       2147.039216    154.823529       38.882353
#  Thailand                        0.000000      0.000000       45.444444
#  Trinadad&Tobago                 0.000000    222.421053       37.368421
#  United-States                1089.229928     88.510593       40.447755
#  Vietnam                       660.597015     87.298507       37.343284
#  Yugoslavia                    347.250000      0.000000       44.562500
#
#                                Target
# Country
#  ?                           0.749571
#  Cambodia                    0.631579
#  Canada                      0.677686
#  China                       0.733333
#  Columbia                    0.966102
#  Cuba                        0.736842
#  Dominican-Republic          0.971429
#  Ecuador                     0.857143
#  El-Salvador                 0.915094
#  England                     0.666667
#  France                      0.586207
#  Germany                     0.678832
#  Greece                      0.724138
#  Guatemala                   0.953125
#  Haiti                       0.909091
#  Holand-Netherlands          1.000000
#  Honduras                    0.923077
#  Hong                        0.700000
#  Hungary                     0.769231
#  India                       0.600000
#  Iran                        0.581395
#  Ireland                     0.791667
#  Italy                       0.657534
#  Jamaica                     0.876543
#  Japan                       0.612903
#  Laos                        0.888889
#  Mexico                      0.948678
#  Nicaragua                   0.941176
#  Outlying-US(Guam-USVI-etc)  1.000000
#  Peru                        0.935484
#  Philippines                 0.691919
#  Poland                      0.800000
#  Portugal                    0.891892
#  Puerto-Rico                 0.894737
#  Scotland                    0.750000
#  South                       0.800000
#  Taiwan                      0.607843
#  Thailand                    0.833333
#  Trinadad&Tobago             0.894737
#  United-States               0.754165
#  Vietnam                     0.925373
#  Yugoslavia                  0.625000

# %%
#dropping un-necessary column from data set
data_set.drop(['Age','fnlwgt','Education-Num','Relationship','Race','Sex','Hours per week'],axis=1,inplace = True)

# %%
#printing data set after dropping columns
data_set
# Out:
#                Workclass    Education       Marital Status  \
# 0              State-gov    Bachelors        Never-married
# 1       Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2                Private      HS-grad             Divorced
# 3                Private         11th   Married-civ-spouse
# 4                Private    Bachelors   Married-civ-spouse
# ...                  ...          ...                  ...
# 32556            Private   Assoc-acdm   Married-civ-spouse
# 32557            Private      HS-grad   Married-civ-spouse
# 32558            Private      HS-grad              Widowed
# 32559            Private      HS-grad        Never-married
# 32560       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                Occupation  Capital Gain  Capital Loss         Country  Target
# 0            Adm-clerical          2174             0   United-States       1
# 1         Exec-managerial             0             0   United-States       1
# 2       Handlers-cleaners             0             0   United-States       1
# 3       Handlers-cleaners             0             0   United-States       1
# 4          Prof-specialty             0             0            Cuba       1
# ...                   ...           ...           ...             ...     ...
# 32556        Tech-support             0             0   United-States       1
# 32557   Machine-op-inspct             0             0   United-States       0
# 32558        Adm-clerical             0             0   United-States       1
# 32559        Adm-clerical             0             0   United-States       1
# 32560     Exec-managerial         15024             0   United-States       0
#
# [32561 rows x 8 columns]

# %%
# changing all catagorical data into numerical data

#these are the column having catagorical data
catagorical_columns =['Workclass','Education','Marital Status','Occupation','Country']

#looping through all columns
for column in catagorical_columns:
    value =1
    # sorting ccatories of the column
    categories = sorted(data_set[column].unique())
    for category in categories:
        data_set.loc[data_set[column] == category, column] = value
        value += 1

# %%
#printing data set after changing values
data_set.head()
# Out:
#    Workclass  Education  Marital Status  Occupation  Capital Gain  \
# 0          8         10               5           2          2174
# 1          7         10               3           5             0
# 2          5         12               1           7             0
# 3          5          2               3           7             0
# 4          5         10               3          11             0
#
#    Capital Loss  Country  Target
# 0             0       40       1
# 1             0       40       1
# 2             0       40       1
# 3             0       40       1
# 4             0        6       1

# %%
#plotting heat map for better evaluation of data 
sns.heatmap(data_set.corr())

# %%
#seeing the data set so that if any column needs re scaling
data_set.describe()
# Out:
#           Workclass     Education  Marital Status    Occupation  Capital Gain  \
# count  32561.000000  32561.000000    32561.000000  32561.000000  32561.000000
# mean       4.868892     11.298210        3.611836      7.572740   1077.648844
# std        1.455960      3.870264        1.506222      4.228857   7385.292085
# min        1.000000      1.000000        1.000000      1.000000      0.000000
# 25%        5.000000     10.000000        3.000000      4.000000      0.000000
# 50%        5.000000     12.000000        3.000000      8.000000      0.000000
# 75%        5.000000     13.000000        5.000000     11.000000      0.000000
# max        9.000000     16.000000        7.000000     15.000000  99999.000000
#
#        Capital Loss       Country        Target
# count  32561.000000  32561.000000  32561.000000
# mean      87.303830     37.718866      0.759190
# std      402.960219      7.823782      0.427581
# min        0.000000      1.000000      0.000000
# 25%        0.000000     40.000000      1.000000
# 50%        0.000000     40.000000      1.000000
# 75%        0.000000     40.000000      1.000000
# max     4356.000000     42.000000      1.000000

# %%
# making rescaling function
def rescaling(col):
    max_value  = data_set[col].min()
    min_value  = data_set[col].max()
    data_set[col] = (data_set[col] - min_value)*10/(max_value - min_value)

# %%
#rescaling capital gain and capital loss column
rescaling('Capital Gain')
rescaling('Capital Loss')

# %%
# describing data set 
data_set.describe()
# Out:
#           Workclass     Education  Marital Status    Occupation  Capital Gain  \
# count  32561.000000  32561.000000    32561.000000  32561.000000  32561.000000
# mean       4.868892     11.298210        3.611836      7.572740      9.892234
# std        1.455960      3.870264        1.506222      4.228857      0.738537
# min        1.000000      1.000000        1.000000      1.000000     -0.000000
# 25%        5.000000     10.000000        3.000000      4.000000     10.000000
# 50%        5.000000     12.000000        3.000000      8.000000     10.000000
# 75%        5.000000     13.000000        5.000000     11.000000     10.000000
# max        9.000000     16.000000        7.000000     15.000000     10.000000
#
#        Capital Loss       Country        Target
# count  32561.000000  32561.000000  32561.000000
# mean       9.799578     37.718866      0.759190
# std        0.925069      7.823782      0.427581
# min       -0.000000      1.000000      0.000000
# 25%       10.000000     40.000000      1.000000
# 50%       10.000000     40.000000      1.000000
# 75%       10.000000     40.000000      1.000000
# max       10.000000     42.000000      1.000000

# %% [markdown]
# ### Seperating train and test data set

# %%
# Splitting 70 % dataset into train set & 30 % dataset into dataset into test set

# selecting random 0.7 fraction of dataset as train set
train = data_set.sample(frac=0.7, random_state=3)   

# chossing different random state will give different random rows
# selecting remaining i.e. 30% as test set
test = data_set.drop(train.index)  

#printing train data set shape and it's head values
print("shape of train data : ",train.shape)
train.head()
# Out:
# shape of train data :  (22793, 8)
#        Workclass  Education  Marital Status  Occupation  Capital Gain  \
# 17650          5         10               3           2          10.0
# 1002           8         12               3          11          10.0
# 11957          5         16               3           2          10.0
# 4669           3         10               3          11          10.0
# 28486          5         12               3           4          10.0
#
#        Capital Loss  Country  Target
# 17650      5.668044       40       0
# 1002      10.000000       40       0
# 11957     10.000000       40       0
# 4669      10.000000       40       0
# 28486     10.000000       40       1

# %%
#printing test data set shape and it's head values
print("shape of test data : ",test.shape)
test.head()
# Out:
# shape of test data :  (9768, 8)
#     Workclass  Education  Marital Status  Occupation  Capital Gain  \
# 2           5         12               1           7     10.000000
# 3           5          2               3           7     10.000000
# 4           5         10               3          11     10.000000
# 8           5         13               5          11      8.591586
# 10          5         16               3           5     10.000000
#
#     Capital Loss  Country  Target
# 2           10.0       40       1
# 3           10.0       40       1
# 4           10.0        6       1
# 8           10.0       40       0
# 10          10.0       40       0

# %%
#defining a method to seperate xtrain,xtest,ytrain,ytest data since there are large number of columns
def split_train_test_x_y(data):   
    #seperating x values
    y_values = np.array(data['Target'])
    #seperating y values
    x_values = np.ones((1,len(data)))
    
    for col in data.columns:
        if col != 'Target':
            new_row = np.array(data[col]).reshape(1,len(data))
            x_values = np.append(x_values, new_row, axis=0)

    return x_values, y_values

# %%
#obtaining x-train,x-test,y-train,y-test values by calling above function
train_x_values, train_y_values = split_train_test_x_y(train)
test_x_values, test_y_values = split_train_test_x_y(test)

# %% [markdown]
# ### making logistic regression model

# %%
# initialising all parameters (theta0, theta1,...theta(n)) to 0 
theta = np.zeros(len(train_x_values))


# total training records
total = len(train) 

# defining prediction fn using sigmoid function using formula
def hypothesis_function(x_values):
    return 1/(1 + np.exp(-(theta.dot(x_values))))

# %%
# defining derivative of cost function
def cost_function(row):
    return (hypothesis_function(train_x_values) - train_y_values).dot(train_x_values[row])/total

# %%
def obtain_theta():
    #taking number of iterations
    iterations = 100 
    #taking learning rate
    alpha = 0.1
    for _ in range(iterations):
        theta_temp = np.copy(theta)
        for index in range(len(theta_temp)):
            theta[index] = theta_temp[index] - alpha * cost_function(index)
    return theta

# %%
# printing final parameters theta0,theta1,.....,theta(n)
theta = obtain_theta()
theta
# Out:
# array([14.46090001,  0.08267395, -0.16578343,  0.52872834,  0.02976409,
#         2.57702644, -1.08573327, -0.70685   ])

# %%
#checking for accuracy of build model

# function that returns accuracy using total predicting correct category
def find_accuracy(predicted_y_values, y_values):
    return (categorise_prediction(predicted_y_values) == y_values).mean()*100

# %%
# categorising predicted values
def categorise_prediction(y_values):
    return np.where(y_values >= 0.5, 1, 0)

# %%
#obtaining accuracy of build model
model_accuracy = find_accuracy(hypothesis_function(test_x_values), test_y_values)
#printing model accuracy obtained
model_accuracy
# Out:
# 76.37182637182637
